# %%
import pandas as pd
import numpy as np

# %%
import requests
import re
import seaborn as sns

# %%
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 20)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
# I define the inicial dataset in the 'inic' variable (should be a string that contain the path of the file) 
# and in the 'dest' variable I do a list with the path of all the files I want concat

def HistMake (inic, dest):
    datatot = pd.read_csv(inic)
    #I make a variable that would be mi fist dataframe
    for i in dest: 
        data0 = pd.read_csv(i)
        datatot = pd.concat([data0,datatot], axis = 0).reset_index(drop=True)
    return datatot
        
def TwoMake (inic, dest):
    datatot = pd.read_csv(inic)
    datatot.columns= datatot.columns.str.lower()
    #I make a variable that would be mi fist dataframe
    data0 = pd.read_csv(dest)
    data0.columns= data0.columns.str.lower()
    datatot = pd.concat([data0,datatot], axis = 0).reset_index(drop=True)
    return datatot

# %% [markdown]
# # Houses Price Historical

# %%
price = ["../datasets/all/comp_vend_preu_trim_2014.csv", "../datasets/all/comp_vend_preu_trim_2015.csv",
       "../datasets/all/comp_vend_preu_trim_2016.csv", "../datasets/all/comp_vend_preu_trim_2017.csv", "../datasets/all/comp_vend_preu_trim_2018.csv",
       "../datasets/all/comp_vend_preu_trim_2019.csv"]

# %%
price_hist = HistMake("../datasets/all/comp_vend_preu_2013.csv", price) 
price_hist
# Out:
#         Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0      2019        1.0               1  Ciutat Vella           1
# 1      2019        1.0               1  Ciutat Vella           2
# 2      2019        1.0               1  Ciutat Vella           3
# 3      2019        1.0               1  Ciutat Vella           4
# 4      2019        1.0               2      Eixample           5
# ...     ...        ...             ...           ...         ...
# 10945  2013        NaN              10    Sant Martí          69
# 10946  2013        NaN              10    Sant Martí          70
# 10947  2013        NaN              10    Sant Martí          71
# 10948  2013        NaN              10    Sant Martí          72
# 10949  2013        NaN              10    Sant Martí          73
#
#                                           Nom_Barri      Preu_mitja_habitatge  \
# 0                                          el Raval     Total. Milers d'euros
# 1                                    el Barri Gòtic     Total. Milers d'euros
# 2                                    la Barceloneta     Total. Milers d'euros
# 3             Sant Pere, Santa Caterina i la Ribera     Total. Milers d'euros
# 4                                     el Fort Pienc     Total. Milers d'euros
# ...                                             ...                       ...
# 10945  Diagonal Mar i el Front Marítim del Poblenou  Usat. Euros/m2 construït
# 10946                         el Besòs i el Maresme  Usat. Euros/m2 construït
# 10947                       Provençals del Poblenou  Usat. Euros/m2 construït
# 10948                      Sant Martí de Provençals  Usat. Euros/m2 construït
# 10949                           la Verneda i la Pau  Usat. Euros/m2 construït
#
#         Valor
# 0       236.7
# 1       411.7
# 2       215.6
# 3       306.0
# 4       582.2
# ...       ...
# 10945  5138.1
# 10946  1811.7
# 10947  3526.9
# 10948  1780.8
# 10949  1471.3
#
# [10950 rows x 8 columns]

# %%
price_hist.isnull().sum()
# Out:
# Year                0
# Trimester         438
# Code_District       0
# Name_Dist           0
# Code_NBHD           0
# Name_NBHD           0
# Desc_Price          0
# Price            2953
# dtype: int64

# %%
price_hist.columns = ['Year', 'Trimester', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Description', 'Price']
price_hist
# Out:
#        Year  Trimester  Code_District     Name_Dist  Code_NBHD  \
# 0      2019        1.0              1  Ciutat Vella          1
# 1      2019        1.0              1  Ciutat Vella          2
# 2      2019        1.0              1  Ciutat Vella          3
# 3      2019        1.0              1  Ciutat Vella          4
# 4      2019        1.0              2      Eixample          5
# ...     ...        ...            ...           ...        ...
# 10945  2013        NaN             10    Sant Martí         69
# 10946  2013        NaN             10    Sant Martí         70
# 10947  2013        NaN             10    Sant Martí         71
# 10948  2013        NaN             10    Sant Martí         72
# 10949  2013        NaN             10    Sant Martí         73
#
#                                           Name_NBHD               Description  \
# 0                                          el Raval     Total. Milers d'euros
# 1                                    el Barri Gòtic     Total. Milers d'euros
# 2                                    la Barceloneta     Total. Milers d'euros
# 3             Sant Pere, Santa Caterina i la Ribera     Total. Milers d'euros
# 4                                     el Fort Pienc     Total. Milers d'euros
# ...                                             ...                       ...
# 10945  Diagonal Mar i el Front Marítim del Poblenou  Usat. Euros/m2 construït
# 10946                         el Besòs i el Maresme  Usat. Euros/m2 construït
# 10947                       Provençals del Poblenou  Usat. Euros/m2 construït
# 10948                      Sant Martí de Provençals  Usat. Euros/m2 construït
# 10949                           la Verneda i la Pau  Usat. Euros/m2 construït
#
#         Price
# 0       236.7
# 1       411.7
# 2       215.6
# 3       306.0
# 4       582.2
# ...       ...
# 10945  5138.1
# 10946  1811.7
# 10947  3526.9
# 10948  1780.8
# 10949  1471.3
#
# [10950 rows x 8 columns]

# %% [markdown]
# # Density Historical

# %%
density = ["../datasets/all/densitat_2014.csv", "../datasets/all/densitat_2015.csv", "../datasets/all/densitat_2016.csv", 
           "../datasets/all/densitat_2017.csv", "../datasets/all/densitat_2018.csv", "../datasets/all/densitat_2019.csv"]

# %%
density_hist = HistMake("../datasets/all/densitat_2013.csv", density) 
density_hist
# Out:
#       Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2019               1  Ciutat Vella           1
# 1    2019               1  Ciutat Vella           2
# 2    2019               1  Ciutat Vella           3
# 3    2019               1  Ciutat Vella           4
# 4    2019               2      Eixample           5
# ..    ...             ...           ...         ...
# 506  2013              10    Sant Martí          69
# 507  2013              10    Sant Martí          70
# 508  2013              10    Sant Martí          71
# 509  2013              10    Sant Martí          72
# 510  2013              10    Sant Martí          73
#
#                                         Nom_Barri  Població  Superfície (ha)  \
# 0                                        el Raval     47353            110.0
# 1                                  el Barri Gòtic     18629             81.6
# 2                                  la Barceloneta     14857            109.5
# 3           Sant Pere, Santa Caterina i la Ribera     22590            111.0
# 4                                   el Fort Pienc     32349             92.9
# ..                                            ...       ...              ...
# 506  Diagonal Mar i el Front Marítim del Poblenou     12894            123.7
# 507                         el Besòs i el Maresme     23118            127.4
# 508                       Provençals del Poblenou     20052            110.5
# 509                      Sant Martí de Provençals     25994             74.5
# 510                           la Verneda i la Pau     29154            112.3
#
#      Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# 0                           49.6                430                     955
# 1                           34.1                228                     546
# 2                           13.5                136                    1097
# 3                           32.4                204                     697
# 4                           33.6                348                     962
# ..                           ...                ...                     ...
# 506                          NaN                104                     560
# 507                          NaN                181                     878
# 508                          NaN                181                    1487
# 509                          NaN                349                    1144
# 510                          NaN                260                     899
#
# [511 rows x 10 columns]

# %%
density_hist.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Population', 
                        'Total_Area(ha)', 'Housing_Area(ha)', 'Density(hab/ha)', 'Real_Density(hab/ha)']

# %%
density_hist.isnull().sum()
# Out:
# Year                      0
# Code_District             0
# Name_Dist                 0
# Code_NBHD                 0
# Name_NBHD                 0
# Population                0
# Total_Area(ha)            0
# Housing_Area(ha)        292
# Density(hab/ha)           0
# Real_Density(hab/ha)      0
# dtype: int64

# %%
density_hist
# Out:
#      Year  Code_District     Name_Dist  Code_NBHD  \
# 0    2019              1  Ciutat Vella          1
# 1    2019              1  Ciutat Vella          2
# 2    2019              1  Ciutat Vella          3
# 3    2019              1  Ciutat Vella          4
# 4    2019              2      Eixample          5
# ..    ...            ...           ...        ...
# 506  2013             10    Sant Martí         69
# 507  2013             10    Sant Martí         70
# 508  2013             10    Sant Martí         71
# 509  2013             10    Sant Martí         72
# 510  2013             10    Sant Martí         73
#
#                                         Name_NBHD  Population  Total_Area(ha)  \
# 0                                        el Raval       47353           110.0
# 1                                  el Barri Gòtic       18629            81.6
# 2                                  la Barceloneta       14857           109.5
# 3           Sant Pere, Santa Caterina i la Ribera       22590           111.0
# 4                                   el Fort Pienc       32349            92.9
# ..                                            ...         ...             ...
# 506  Diagonal Mar i el Front Marítim del Poblenou       12894           123.7
# 507                         el Besòs i el Maresme       23118           127.4
# 508                       Provençals del Poblenou       20052           110.5
# 509                      Sant Martí de Provençals       25994            74.5
# 510                           la Verneda i la Pau       29154           112.3
#
#      Housing_Area(ha)  Density(hab/ha)  Real_Density(hab/ha)
# 0                49.6              430                   955
# 1                34.1              228                   546
# 2                13.5              136                  1097
# 3                32.4              204                   697
# 4                33.6              348                   962
# ..                ...              ...                   ...
# 506               NaN              104                   560
# 507               NaN              181                   878
# 508               NaN              181                  1487
# 509               NaN              349                  1144
# 510               NaN              260                   899
#
# [511 rows x 10 columns]

# %% [markdown]
# # Composition of the Houses Ages

# %%
aa = TwoMake("../datasets/all/domicilis_edat_mitjana_nacionalitat_2019.csv", "../datasets/all/domicilis_edat_mitjana_nacionalitat_2018.csv")
aa
# Out:
#       any  codi_districte nom_districte  codi_barri  \
# 0    2018               1  Ciutat Vella           1
# 1    2018               1  Ciutat Vella           2
# 2    2018               1  Ciutat Vella           3
# 3    2018               1  Ciutat Vella           4
# 4    2018               2      Eixample           5
# ..    ...             ...           ...         ...
# 433  2019              10    Sant Martí          69
# 434  2019              10    Sant Martí          70
# 435  2019              10    Sant Martí          71
# 436  2019              10    Sant Martí          72
# 437  2019              10    Sant Martí          73
#
#                                         nom_barri    nacionalitat  \
# 0                                        el Raval  Tots espanyols
# 1                                  el Barri Gòtic  Tots espanyols
# 2                                  la Barceloneta  Tots espanyols
# 3           Sant Pere, Santa Caterina i la Ribera  Tots espanyols
# 4                                   el Fort Pienc  Tots espanyols
# ..                                            ...             ...
# 433  Diagonal Mar i el Front Marítim del Poblenou             NaN
# 434                         el Besòs i el Maresme             NaN
# 435                       Provençals del Poblenou             NaN
# 436                      Sant Martí de Provençals             NaN
# 437                           la Verneda i la Pau             NaN
#
#      edat_mitjana            nombre
# 0       49.900000               NaN
# 1       50.800000               NaN
# 2       50.100000               NaN
# 3       49.400000               NaN
# 4       49.000000               NaN
# ..            ...               ...
# 433     34.024517  Domicilis mixtos
# 434     32.744687  Domicilis mixtos
# 435     34.895161  Domicilis mixtos
# 436     36.757025  Domicilis mixtos
# 437     35.216807  Domicilis mixtos
#
# [438 rows x 8 columns]

# %%
aa.loc[aa['nombre'].notnull(), "nacionalitat"] = aa["nombre"]

# %%
aa.nacionalitat.value_counts()
# Out:
# Tots estrangers     146
# Tots espanyols      146
# Domicilis mixtos    146
# Name: nacionalitat, dtype: int64

# %%
aa.isnull().sum()
# Out:
# any                 0
# codi_districte      0
# nom_districte       0
# codi_barri          0
# nom_barri           0
# nacionalitat        0
# edat_mitjana        0
# nombre            219
# dtype: int64

# %%
aa.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Nationality', 'Avererage_Age', 'Name']

# %%
comp_hist = aa.iloc[:,0:-1]

# %%
comp_hist
# Out:
#      Year  Code_District     Name_Dist  Code_NBHD  \
# 0    2018              1  Ciutat Vella          1
# 1    2018              1  Ciutat Vella          2
# 2    2018              1  Ciutat Vella          3
# 3    2018              1  Ciutat Vella          4
# 4    2018              2      Eixample          5
# ..    ...            ...           ...        ...
# 433  2019             10    Sant Martí         69
# 434  2019             10    Sant Martí         70
# 435  2019             10    Sant Martí         71
# 436  2019             10    Sant Martí         72
# 437  2019             10    Sant Martí         73
#
#                                         Name_NBHD       Nationality  \
# 0                                        el Raval    Tots espanyols
# 1                                  el Barri Gòtic    Tots espanyols
# 2                                  la Barceloneta    Tots espanyols
# 3           Sant Pere, Santa Caterina i la Ribera    Tots espanyols
# 4                                   el Fort Pienc    Tots espanyols
# ..                                            ...               ...
# 433  Diagonal Mar i el Front Marítim del Poblenou  Domicilis mixtos
# 434                         el Besòs i el Maresme  Domicilis mixtos
# 435                       Provençals del Poblenou  Domicilis mixtos
# 436                      Sant Martí de Provençals  Domicilis mixtos
# 437                           la Verneda i la Pau  Domicilis mixtos
#
#      Avererage_Age
# 0        49.900000
# 1        50.800000
# 2        50.100000
# 3        49.400000
# 4        49.000000
# ..             ...
# 433      34.024517
# 434      32.744687
# 435      34.895161
# 436      36.757025
# 437      35.216807
#
# [438 rows x 7 columns]

# %% [markdown]
# # Composition of the Houses Nationality

# %%
comp = TwoMake("../datasets/all/domicilis_nacionalitat_2018.csv", "../datasets/all/domicilis_nacionalitat_2019.csv")
comp
# Out:
#       any  codi_districte nom_districte  codi_barri  \
# 0    2019               1  Ciutat Vella           1
# 1    2019               1  Ciutat Vella           2
# 2    2019               1  Ciutat Vella           3
# 3    2019               1  Ciutat Vella           4
# 4    2019               2      Eixample           5
# ..    ...             ...           ...         ...
# 433  2018              10    Sant Martí          69
# 434  2018              10    Sant Martí          70
# 435  2018              10    Sant Martí          71
# 436  2018              10    Sant Martí          72
# 437  2018              10    Sant Martí          73
#
#                                         nom_barri      nacionalitat  nombre
# 0                                        el Raval    Tots espanyols    8025
# 1                                  el Barri Gòtic    Tots espanyols    3105
# 2                                  la Barceloneta    Tots espanyols    3896
# 3           Sant Pere, Santa Caterina i la Ribera    Tots espanyols    5305
# 4                                   el Fort Pienc    Tots espanyols    9533
# ..                                            ...               ...     ...
# 433  Diagonal Mar i el Front Marítim del Poblenou  Domicilis mixtos     512
# 434                         el Besòs i el Maresme  Domicilis mixtos     911
# 435                       Provençals del Poblenou  Domicilis mixtos     750
# 436                      Sant Martí de Provençals  Domicilis mixtos     801
# 437                           la Verneda i la Pau  Domicilis mixtos     838
#
# [438 rows x 7 columns]

# %%
comp.isnull().sum()
# Out:
# Year             0
# Code_District    0
# Name_Dist        0
# Code_NBHD        0
# Name_NBHD        0
# Nationality      0
# People           0
# dtype: int64

# %%
comp.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Nationality', 'People']

# %% [markdown]
# # Nationality

# %%
ine = TwoMake("../datasets/all/ine_nacionalitat_per_sexe_2018.csv", "../datasets/all/ine_nacionalitat_per_sexe_2019.csv")
ine
# Out:
#         any  codi_districte nom_districte  codi_barri  \
# 0      2019               1  Ciutat Vella           1
# 1      2019               1  Ciutat Vella           2
# 2      2019               1  Ciutat Vella           3
# 3      2019               1  Ciutat Vella           4
# 4      2019               2      Eixample           5
# ...     ...             ...           ...         ...
# 52409  2018              10    Sant Martí          69
# 52410  2018              10    Sant Martí          70
# 52411  2018              10    Sant Martí          71
# 52412  2018              10    Sant Martí          72
# 52413  2018              10    Sant Martí          73
#
#                                           nom_barri  sexe nacionalitat  nombre
# 0                                          el Raval  Dona      Espanya   11666
# 1                                    el Barri Gòtic  Dona      Espanya    4214
# 2                                    la Barceloneta  Dona      Espanya    4801
# 3             Sant Pere, Santa Caterina i la Ribera  Dona      Espanya    6570
# 4                                     el Fort Pienc  Dona      Espanya   13074
# ...                                             ...   ...          ...     ...
# 52409  Diagonal Mar i el Front Marítim del Poblenou  Dona    Apàtrides       0
# 52410                         el Besòs i el Maresme  Dona    Apàtrides       1
# 52411                       Provençals del Poblenou  Dona    Apàtrides       0
# 52412                      Sant Martí de Provençals  Dona    Apàtrides       0
# 52413                           la Verneda i la Pau  Dona    Apàtrides       1
#
# [52414 rows x 8 columns]

# %%
ine.isnull().sum()
# Out:
# any               0
# codi_districte    0
# nom_districte     0
# codi_barri        0
# nom_barri         0
# sexe              0
# nacionalitat      0
# nombre            0
# dtype: int64

# %%
ine.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Gender' ,'Nationality', 'People']

# %%
ine
# Out:
#        Year  Code_District     Name_Dist  Code_NBHD  \
# 0      2019              1  Ciutat Vella          1
# 1      2019              1  Ciutat Vella          2
# 2      2019              1  Ciutat Vella          3
# 3      2019              1  Ciutat Vella          4
# 4      2019              2      Eixample          5
# ...     ...            ...           ...        ...
# 52409  2018             10    Sant Martí         69
# 52410  2018             10    Sant Martí         70
# 52411  2018             10    Sant Martí         71
# 52412  2018             10    Sant Martí         72
# 52413  2018             10    Sant Martí         73
#
#                                           Name_NBHD Gender Nationality  People
# 0                                          el Raval   Dona     Espanya   11666
# 1                                    el Barri Gòtic   Dona     Espanya    4214
# 2                                    la Barceloneta   Dona     Espanya    4801
# 3             Sant Pere, Santa Caterina i la Ribera   Dona     Espanya    6570
# 4                                     el Fort Pienc   Dona     Espanya   13074
# ...                                             ...    ...         ...     ...
# 52409  Diagonal Mar i el Front Marítim del Poblenou   Dona   Apàtrides       0
# 52410                         el Besòs i el Maresme   Dona   Apàtrides       1
# 52411                       Provençals del Poblenou   Dona   Apàtrides       0
# 52412                      Sant Martí de Provençals   Dona   Apàtrides       0
# 52413                           la Verneda i la Pau   Dona   Apàtrides       1
#
# [52414 rows x 8 columns]

# %% [markdown]
# # Price for Rent Historical

# %%
dic = ["../datasets/all/lloguer_preu_trim_2015.csv", "../datasets/all/lloguer_preu_trim_2016.csv", 
       "../datasets/all/lloguer_preu_trim_2017.csv", "../datasets/all/lloguer_preu_trim_2018.csv",
       "../datasets/all/lloguer_preu_trim_2019.csv", "../datasets/all/lloguer_preu_trim_2020.csv"]

# %%
rent_price = HistMake("../datasets/all/lloguer_preu_trim_2014.csv", dic) 
rent_price
# Out:
#        Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0     2020          1               1  Ciutat Vella           1
# 1     2020          1               1  Ciutat Vella           2
# 2     2020          1               1  Ciutat Vella           3
# 3     2020          1               1  Ciutat Vella           4
# 4     2020          1               2      Eixample           5
# ...    ...        ...             ...           ...         ...
# 3791  2014          4              10    Sant Martí          69
# 3792  2014          4              10    Sant Martí          70
# 3793  2014          4              10    Sant Martí          71
# 3794  2014          4              10    Sant Martí          72
# 3795  2014          4              10    Sant Martí          73
#
#                                          Nom_Barri  \
# 0                                         el Raval
# 1                                   el Barri Gòtic
# 2                                   la Barceloneta
# 3            Sant Pere, Santa Caterina i la Ribera
# 4                                    el Fort Pienc
# ...                                            ...
# 3791  Diagonal Mar i el Front Marítim del Poblenou
# 3792                         el Besòs i el Maresme
# 3793                       Provençals del Poblenou
# 3794                      Sant Martí de Provençals
# 3795                           la Verneda i la Pau
#
#                                     Lloguer_mitja     Preu
# 0               Lloguer mitjà mensual (Euros/mes)   864.50
# 1               Lloguer mitjà mensual (Euros/mes)  1110.20
# 2               Lloguer mitjà mensual (Euros/mes)   899.50
# 3               Lloguer mitjà mensual (Euros/mes)  1030.00
# 4               Lloguer mitjà mensual (Euros/mes)  1059.90
# ...                                           ...      ...
# 3791  Lloguer mitjà per superfície (Euros/m2 mes)    11.49
# 3792  Lloguer mitjà per superfície (Euros/m2 mes)     8.09
# 3793  Lloguer mitjà per superfície (Euros/m2 mes)    10.03
# 3794  Lloguer mitjà per superfície (Euros/m2 mes)     8.86
# 3795  Lloguer mitjà per superfície (Euros/m2 mes)     8.14
#
# [3796 rows x 8 columns]

# %%
rent_price.columns = ['Year', 'Trimester', 'Code_District', 'Name_Dist', 'Code_NBHD',
                      'Name_NBHD', 'Description', 'Price']

# %%
rent_price
# Out:
#       Year  Trimester  Code_District     Name_Dist  Code_NBHD  \
# 0     2020          1              1  Ciutat Vella          1
# 1     2020          1              1  Ciutat Vella          2
# 2     2020          1              1  Ciutat Vella          3
# 3     2020          1              1  Ciutat Vella          4
# 4     2020          1              2      Eixample          5
# ...    ...        ...            ...           ...        ...
# 3791  2014          4             10    Sant Martí         69
# 3792  2014          4             10    Sant Martí         70
# 3793  2014          4             10    Sant Martí         71
# 3794  2014          4             10    Sant Martí         72
# 3795  2014          4             10    Sant Martí         73
#
#                                          Name_NBHD  \
# 0                                         el Raval
# 1                                   el Barri Gòtic
# 2                                   la Barceloneta
# 3            Sant Pere, Santa Caterina i la Ribera
# 4                                    el Fort Pienc
# ...                                            ...
# 3791  Diagonal Mar i el Front Marítim del Poblenou
# 3792                         el Besòs i el Maresme
# 3793                       Provençals del Poblenou
# 3794                      Sant Martí de Provençals
# 3795                           la Verneda i la Pau
#
#                                       Description    Price
# 0               Lloguer mitjà mensual (Euros/mes)   864.50
# 1               Lloguer mitjà mensual (Euros/mes)  1110.20
# 2               Lloguer mitjà mensual (Euros/mes)   899.50
# 3               Lloguer mitjà mensual (Euros/mes)  1030.00
# 4               Lloguer mitjà mensual (Euros/mes)  1059.90
# ...                                           ...      ...
# 3791  Lloguer mitjà per superfície (Euros/m2 mes)    11.49
# 3792  Lloguer mitjà per superfície (Euros/m2 mes)     8.09
# 3793  Lloguer mitjà per superfície (Euros/m2 mes)    10.03
# 3794  Lloguer mitjà per superfície (Euros/m2 mes)     8.86
# 3795  Lloguer mitjà per superfície (Euros/m2 mes)     8.14
#
# [3796 rows x 8 columns]

# %% [markdown]
# # Average Age for Disctrict

# %%
age = TwoMake("../datasets/all/loc_hab_edat_mitjana_2018.csv", "../datasets/all/loc_hab_edat_mitjana_2018.csv")
age
# Out:
#        any  codi_districte nom_districte  codi_barri            nom_barri  \
# 0     2018               1  Ciutat Vella           1             el Raval
# 1     2018               1  Ciutat Vella           1             el Raval
# 2     2018               1  Ciutat Vella           1             el Raval
# 3     2018               1  Ciutat Vella           1             el Raval
# 4     2018               1  Ciutat Vella           1             el Raval
# ...    ...             ...           ...         ...                  ...
# 2131  2018              10    Sant Martí          73  la Verneda i la Pau
# 2132  2018              10    Sant Martí          73  la Verneda i la Pau
# 2133  2018              10    Sant Martí          73  la Verneda i la Pau
# 2134  2018              10    Sant Martí          73  la Verneda i la Pau
# 2135  2018              10    Sant Martí          73  la Verneda i la Pau
#
#       seccio_censal  edat_mitjana
# 0                 1          68.0
# 1                 2         106.3
# 2                 3          90.4
# 3                 4          87.0
# 4                 5         100.0
# ...             ...           ...
# 2131            139          52.4
# 2132            140          54.6
# 2133            141          45.7
# 2134            142          52.0
# 2135            143          55.0
#
# [2136 rows x 7 columns]

# %%
age.isnull().sum()
# Out:
# any               0
# codi_districte    0
# nom_districte     0
# codi_barri        0
# nom_barri         0
# seccio_censal     0
# edat_mitjana      0
# dtype: int64

# %%
age.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Censal_Section' ,'Aver_Age']

# %%
age
# Out:
#       Year  Code_District     Name_Dist  Code_NBHD            Name_NBHD  \
# 0     2018              1  Ciutat Vella          1             el Raval
# 1     2018              1  Ciutat Vella          1             el Raval
# 2     2018              1  Ciutat Vella          1             el Raval
# 3     2018              1  Ciutat Vella          1             el Raval
# 4     2018              1  Ciutat Vella          1             el Raval
# ...    ...            ...           ...        ...                  ...
# 2131  2018             10    Sant Martí         73  la Verneda i la Pau
# 2132  2018             10    Sant Martí         73  la Verneda i la Pau
# 2133  2018             10    Sant Martí         73  la Verneda i la Pau
# 2134  2018             10    Sant Martí         73  la Verneda i la Pau
# 2135  2018             10    Sant Martí         73  la Verneda i la Pau
#
#       Censal_Section  Aver_Age
# 0                  1      68.0
# 1                  2     106.3
# 2                  3      90.4
# 3                  4      87.0
# 4                  5     100.0
# ...              ...       ...
# 2131             139      52.4
# 2132             140      54.6
# 2133             141      45.7
# 2134             142      52.0
# 2135             143      55.0
#
# [2136 rows x 7 columns]

# %% [markdown]
# # Area of the Houses

# %%
sup = TwoMake("../datasets/all/loc_hab_sup_2018.csv", "../datasets/all/loc_hab_sup_2019.csv")
sup
# Out:
#         any  codi_districte nom_districte  codi_barri            nom_barri  \
# 0      2019               1  Ciutat Vella           1             el Raval
# 1      2019               1  Ciutat Vella           1             el Raval
# 2      2019               1  Ciutat Vella           1             el Raval
# 3      2019               1  Ciutat Vella           1             el Raval
# 4      2019               1  Ciutat Vella           1             el Raval
# ...     ...             ...           ...         ...                  ...
# 12915  2018              10    Sant Martí          73  la Verneda i la Pau
# 12916  2018              10    Sant Martí          73  la Verneda i la Pau
# 12917  2018              10    Sant Martí          73  la Verneda i la Pau
# 12918  2018              10    Sant Martí          73  la Verneda i la Pau
# 12919  2018              10    Sant Martí          73  la Verneda i la Pau
#
#        seccio_censal      desc_sup  nombre
# 0                  1  Fins a 30 m2     111
# 1                  1     31- 60 m2     324
# 2                  1     61- 90 m2     222
# 3                  1    91- 120 m2     105
# 4                  1   121- 150 m2      27
# ...              ...           ...     ...
# 12915            142     31- 60 m2     326
# 12916            142     61- 90 m2     285
# 12917            142    91- 120 m2      60
# 12918            143     31- 60 m2     475
# 12919            143     61- 90 m2     570
#
# [12920 rows x 8 columns]

# %%
sup.isnull().sum()
# Out:
# any               0
# codi_districte    0
# nom_districte     0
# codi_barri        0
# nom_barri         0
# seccio_censal     0
# desc_sup          0
# nombre            0
# dtype: int64

# %%
sup.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Censal_Section' , 'Description','Amount']

# %%
sup
# Out:
#        Year  Code_District     Name_Dist  Code_NBHD            Name_NBHD  \
# 0      2019              1  Ciutat Vella          1             el Raval
# 1      2019              1  Ciutat Vella          1             el Raval
# 2      2019              1  Ciutat Vella          1             el Raval
# 3      2019              1  Ciutat Vella          1             el Raval
# 4      2019              1  Ciutat Vella          1             el Raval
# ...     ...            ...           ...        ...                  ...
# 12915  2018             10    Sant Martí         73  la Verneda i la Pau
# 12916  2018             10    Sant Martí         73  la Verneda i la Pau
# 12917  2018             10    Sant Martí         73  la Verneda i la Pau
# 12918  2018             10    Sant Martí         73  la Verneda i la Pau
# 12919  2018             10    Sant Martí         73  la Verneda i la Pau
#
#        Censal_Section   Description  Amount
# 0                   1  Fins a 30 m2     111
# 1                   1     31- 60 m2     324
# 2                   1     61- 90 m2     222
# 3                   1    91- 120 m2     105
# 4                   1   121- 150 m2      27
# ...               ...           ...     ...
# 12915             142     31- 60 m2     326
# 12916             142     61- 90 m2     285
# 12917             142    91- 120 m2      60
# 12918             143     31- 60 m2     475
# 12919             143     61- 90 m2     570
#
# [12920 rows x 8 columns]

# %% [markdown]
# # Average Area of Houses

# %%
supmid = TwoMake("../datasets/all/loc_hab_sup_mitjana_2018.csv", "../datasets/all/loc_hab_sup_mitjana_2018.csv")
supmid
# Out:
#        any  codi_districte nom_districte  codi_barri            nom_barri  \
# 0     2018               1  Ciutat Vella           1             el Raval
# 1     2018               1  Ciutat Vella           1             el Raval
# 2     2018               1  Ciutat Vella           1             el Raval
# 3     2018               1  Ciutat Vella           1             el Raval
# 4     2018               1  Ciutat Vella           1             el Raval
# ...    ...             ...           ...         ...                  ...
# 2131  2018              10    Sant Martí          73  la Verneda i la Pau
# 2132  2018              10    Sant Martí          73  la Verneda i la Pau
# 2133  2018              10    Sant Martí          73  la Verneda i la Pau
# 2134  2018              10    Sant Martí          73  la Verneda i la Pau
# 2135  2018              10    Sant Martí          73  la Verneda i la Pau
#
#       seccio_censal  sup_mitjana_m2
# 0                 1            76.8
# 1                 2            71.6
# 2                 3            59.0
# 3                 4            65.3
# 4                 5            77.9
# ...             ...             ...
# 2131            139            59.9
# 2132            140            75.5
# 2133            141            75.5
# 2134            142            71.0
# 2135            143            66.3
#
# [2136 rows x 7 columns]

# %%
supmid.isnull().sum()
# Out:
# any               0
# codi_districte    0
# nom_districte     0
# codi_barri        0
# nom_barri         0
# seccio_censal     0
# sup_mitjana_m2    0
# dtype: int64

# %%
supmid.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Censal_Section' , 'Average_Area']

# %%
supmid
# Out:
#       Year  Code_District     Name_Dist  Code_NBHD            Name_NBHD  \
# 0     2018              1  Ciutat Vella          1             el Raval
# 1     2018              1  Ciutat Vella          1             el Raval
# 2     2018              1  Ciutat Vella          1             el Raval
# 3     2018              1  Ciutat Vella          1             el Raval
# 4     2018              1  Ciutat Vella          1             el Raval
# ...    ...            ...           ...        ...                  ...
# 2131  2018             10    Sant Martí         73  la Verneda i la Pau
# 2132  2018             10    Sant Martí         73  la Verneda i la Pau
# 2133  2018             10    Sant Martí         73  la Verneda i la Pau
# 2134  2018             10    Sant Martí         73  la Verneda i la Pau
# 2135  2018             10    Sant Martí         73  la Verneda i la Pau
#
#       Censal_Section  Average_Area
# 0                  1          76.8
# 1                  2          71.6
# 2                  3          59.0
# 3                  4          65.3
# 4                  5          77.9
# ...              ...           ...
# 2131             139          59.9
# 2132             140          75.5
# 2133             141          75.5
# 2134             142          71.0
# 2135             143          66.3
#
# [2136 rows x 7 columns]

# %% [markdown]
# # Local by Use

# %%
loc = TwoMake("../datasets/all/locals_us_desti_2018.csv", "../datasets/all/locals_us_desti_2019.csv")
loc
# Out:
#         any  \
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 52714  2018
# 52715  2018
# 52716  2018
# 52717  2018
# 52718  2018
#
#       codi_districte  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 52714             10
# 52715             10
# 52716             10
# 52717             10
# 52718             10
#
#       nom_districte  \
# 0      Ciutat Vella
# 1      Ciutat Vella
# 2      Ciutat Vella
# 3      Ciutat Vella
# 4      Ciutat Vella
# ...             ...
# 52714    Sant Martí
# 52715    Sant Martí
# 52716    Sant Martí
# 52717    Sant Martí
# 52718    Sant Martí
#
#       codi_barri  \
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 52714         73
# 52715         73
# 52716         73
# 52717         73
# 52718         73
#
#                  nom_barri  \
# 0                 el Raval
# 1                 el Raval
# 2                 el Raval
# 3                 el Raval
# 4                 el Raval
# ...                    ...
# 52714  la Verneda i la Pau
# 52715  la Verneda i la Pau
# 52716  la Verneda i la Pau
# 52717  la Verneda i la Pau
# 52718  la Verneda i la Pau
#
#       seccio_censal  \
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 52714           142
# 52715           143
# 52716           143
# 52717           143
# 52718           143
#
#       desc_us_desti_principal  \
# 0                Habitatge
# 1              Aparcaments
# 2                   Comerç
# 3                 Magatzem
# 4                  Oficina
# ...                    ...
# 52714             Religiós
# 52715            Habitatge
# 52716               Comerç
# 52717                Hotel
# 52718          Ensenyament
#
#       concepte  \
# 0       Nombre
# 1       Nombre
# 2       Nombre
# 3       Nombre
# 4       Nombre
# ...        ...
# 52714  Valor_€
# 52715  Valor_€
# 52716  Valor_€
# 52717  Valor_€
# 52718  Valor_€
#
#               nombre
# 0             819.00
# 1              98.00
# 2              50.00
# 3              30.00
# 4             157.00
# ...              ...
# 52714      822218.98
# 52715 37618731925.00
# 52716   601580565.00
# 52717       55101.37
# 52718     2120855.00
#
# [52719 rows x 9 columns]

# %%
loc.isnull().sum()
# Out:
# any                        0
# codi_districte             0
# nom_districte              0
# codi_barri                 0
# nom_barri                  0
# seccio_censal              0
# desc_us_desti_principal    0
# concepte                   0
# nombre                     0
# dtype: int64

# %%
loc.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD', 'Name_NBHD', 'Censal_Section' ,'Use', "Description" , 'Amount']

# %%
supmid
# Out:
#       Year  Code_District     Name_Dist  Code_NBHD            Name_NBHD  \
# 0     2018              1  Ciutat Vella          1             el Raval
# 1     2018              1  Ciutat Vella          1             el Raval
# 2     2018              1  Ciutat Vella          1             el Raval
# 3     2018              1  Ciutat Vella          1             el Raval
# 4     2018              1  Ciutat Vella          1             el Raval
# ...    ...            ...           ...        ...                  ...
# 2131  2018             10    Sant Martí         73  la Verneda i la Pau
# 2132  2018             10    Sant Martí         73  la Verneda i la Pau
# 2133  2018             10    Sant Martí         73  la Verneda i la Pau
# 2134  2018             10    Sant Martí         73  la Verneda i la Pau
# 2135  2018             10    Sant Martí         73  la Verneda i la Pau
#
#       Censal_Section  Average_Area
# 0                  1          76.8
# 1                  2          71.6
# 2                  3          59.0
# 3                  4          65.3
# 4                  5          77.9
# ...              ...           ...
# 2131             139          59.9
# 2132             140          75.5
# 2133             141          75.5
# 2134             142          71.0
# 2135             143          66.3
#
# [2136 rows x 7 columns]

# %%
loc
# Out:
#        Year  \
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
# ...     ...
# 52714  2018
# 52715  2018
# 52716  2018
# 52717  2018
# 52718  2018
#
#       Code_District  \
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 52714            10
# 52715            10
# 52716            10
# 52717            10
# 52718            10
#
#           Name_Dist  \
# 0      Ciutat Vella
# 1      Ciutat Vella
# 2      Ciutat Vella
# 3      Ciutat Vella
# 4      Ciutat Vella
# ...             ...
# 52714    Sant Martí
# 52715    Sant Martí
# 52716    Sant Martí
# 52717    Sant Martí
# 52718    Sant Martí
#
#       Code_NBHD  \
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 52714        73
# 52715        73
# 52716        73
# 52717        73
# 52718        73
#
#                  Name_NBHD  \
# 0                 el Raval
# 1                 el Raval
# 2                 el Raval
# 3                 el Raval
# 4                 el Raval
# ...                    ...
# 52714  la Verneda i la Pau
# 52715  la Verneda i la Pau
# 52716  la Verneda i la Pau
# 52717  la Verneda i la Pau
# 52718  la Verneda i la Pau
#
#       Censal_Section  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 52714            142
# 52715            143
# 52716            143
# 52717            143
# 52718            143
#
#                Use  \
# 0        Habitatge
# 1      Aparcaments
# 2           Comerç
# 3         Magatzem
# 4          Oficina
# ...            ...
# 52714     Religiós
# 52715    Habitatge
# 52716       Comerç
# 52717        Hotel
# 52718  Ensenyament
#
#       Description  \
# 0          Nombre
# 1          Nombre
# 2          Nombre
# 3          Nombre
# 4          Nombre
# ...           ...
# 52714     Valor_€
# 52715     Valor_€
# 52716     Valor_€
# 52717     Valor_€
# 52718     Valor_€
#
#               Amount
# 0             819.00
# 1              98.00
# 2              50.00
# 3              30.00
# 4             157.00
# ...              ...
# 52714      822218.98
# 52715 37618731925.00
# 52716   601580565.00
# 52717       55101.37
# 52718     2120855.00
#
# [52719 rows x 9 columns]

# %% [markdown]
# # Ages and Nationality

# %%
dic = ["../datasets/all/padro_edat_quinquennal_per_nacionalitat_i_sexe_2018.csv",
       "../datasets/all/padro_edat_quinquennal_per_nacionalitat_i_sexe_2019.csv",
       "../datasets/all/padro_edat_quinquennal_per_nacionalitat_i_sexe_2020.csv"]

# %%
age_nat = HistMake("../datasets/all/padro_edat_quinquennal_per_nacionalitat_i_sexe_2017.csv", dic) 
age_nat
# Out:
#         Any  \
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 24523  2017
# 24524  2017
# 24525  2017
# 24526  2017
# 24527  2017
#
#        Codi_Districte  \
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   2
# ...               ...
# 24523              10
# 24524              10
# 24525              10
# 24526              10
# 24527              10
#
#       Nom_Districte  \
# 0      Ciutat Vella
# 1      Ciutat Vella
# 2      Ciutat Vella
# 3      Ciutat Vella
# 4          Eixample
# ...             ...
# 24523    Sant Martí
# 24524    Sant Martí
# 24525    Sant Martí
# 24526    Sant Martí
# 24527    Sant Martí
#
#        Codi_Barri  \
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 24523          69
# 24524          70
# 24525          71
# 24526          72
# 24527          73
#
#                  Nom_Barri  \
# 0                 el Raval
# 1           el Barri Gòtic
# 2           la Barceloneta
# 3      Sant Pere, Santa...
# 4            el Fort Pienc
# ...                    ...
# 24523  Diagonal Mar i e...
# 24524  el Besòs i el Ma...
# 24525  Provençals del P...
# 24526  Sant Martí de Pr...
# 24527  la Verneda i la Pau
#
#        Sexe  \
# 0      Dona
# 1      Dona
# 2      Dona
# 3      Dona
# 4      Dona
# ...     ...
# 24523  Dona
# 24524  Dona
# 24525  Dona
# 24526  Dona
# 24527  Dona
#
#       Nacionalitat  \
# 0        Espanyola
# 1        Espanyola
# 2        Espanyola
# 3        Espanyola
# 4        Espanyola
# ...            ...
# 24523   Estrangera
# 24524   Estrangera
# 24525   Estrangera
# 24526   Estrangera
# 24527   Estrangera
#
#       Edat_quinquennal  \
# 0             0-4 anys
# 1             0-4 anys
# 2             0-4 anys
# 3             0-4 anys
# 4             0-4 anys
# ...                ...
# 24523   100 anys i més
# 24524   100 anys i més
# 24525   100 anys i més
# 24526   100 anys i més
# 24527   100 anys i més
#
#        Nombre
# 0         395
# 1         102
# 2         131
# 3         185
# 4         419
# ...       ...
# 24523       0
# 24524       0
# 24525       0
# 24526       0
# 24527       0
#
# [24528 rows x 9 columns]

# %%
age_nat.columns = ['Year', 'Code_District', 'Name_Dist', 'Code_NBHD',
                      'Name_NBHD', 'Gender', 'Nationality', 'Age', 'Amount']

# %%
age_nat
# Out:
#        Year  \
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 24523  2017
# 24524  2017
# 24525  2017
# 24526  2017
# 24527  2017
#
#        Code_District  \
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  2
# ...              ...
# 24523             10
# 24524             10
# 24525             10
# 24526             10
# 24527             10
#
#           Name_Dist  \
# 0      Ciutat Vella
# 1      Ciutat Vella
# 2      Ciutat Vella
# 3      Ciutat Vella
# 4          Eixample
# ...             ...
# 24523    Sant Martí
# 24524    Sant Martí
# 24525    Sant Martí
# 24526    Sant Martí
# 24527    Sant Martí
#
#        Code_NBHD  \
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 24523         69
# 24524         70
# 24525         71
# 24526         72
# 24527         73
#
#                  Name_NBHD  \
# 0                 el Raval
# 1           el Barri Gòtic
# 2           la Barceloneta
# 3      Sant Pere, Santa...
# 4            el Fort Pienc
# ...                    ...
# 24523  Diagonal Mar i e...
# 24524  el Besòs i el Ma...
# 24525  Provençals del P...
# 24526  Sant Martí de Pr...
# 24527  la Verneda i la Pau
#
#       Gender  \
# 0       Dona
# 1       Dona
# 2       Dona
# 3       Dona
# 4       Dona
# ...      ...
# 24523   Dona
# 24524   Dona
# 24525   Dona
# 24526   Dona
# 24527   Dona
#
#       Nationality  \
# 0       Espanyola
# 1       Espanyola
# 2       Espanyola
# 3       Espanyola
# 4       Espanyola
# ...           ...
# 24523  Estrangera
# 24524  Estrangera
# 24525  Estrangera
# 24526  Estrangera
# 24527  Estrangera
#
#                   Age  \
# 0            0-4 anys
# 1            0-4 anys
# 2            0-4 anys
# 3            0-4 anys
# 4            0-4 anys
# ...               ...
# 24523  100 anys i més
# 24524  100 anys i més
# 24525  100 anys i més
# 24526  100 anys i més
# 24527  100 anys i més
#
#        Amount
# 0         395
# 1         102
# 2         131
# 3         185
# 4         419
# ...       ...
# 24523       0
# 24524       0
# 24525       0
# 24526       0
# 24527       0
#
# [24528 rows x 9 columns]
