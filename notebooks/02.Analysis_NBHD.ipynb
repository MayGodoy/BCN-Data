# %%
import pandas as pd
import numpy as np

# %%
import requests
import re
import seaborn as sns

# %%
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 20)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data = pd.read_csv("../datasets/Houses_Area.csv")
data
# Out:
#        Year  Code_District     Name_Dist  Code_NBHD            Name_NBHD  \
# 0      2019              1  Ciutat Vella          1             el Raval
# 1      2019              1  Ciutat Vella          1             el Raval
# 2      2019              1  Ciutat Vella          1             el Raval
# 3      2019              1  Ciutat Vella          1             el Raval
# 4      2019              1  Ciutat Vella          1             el Raval
# ...     ...            ...           ...        ...                  ...
# 12915  2018             10    Sant Martí         73  la Verneda i la Pau
# 12916  2018             10    Sant Martí         73  la Verneda i la Pau
# 12917  2018             10    Sant Martí         73  la Verneda i la Pau
# 12918  2018             10    Sant Martí         73  la Verneda i la Pau
# 12919  2018             10    Sant Martí         73  la Verneda i la Pau
#
#        Censal_Section   Description  Amount
# 0                   1  Fins a 30 m2     111
# ...

# %%
data = pd.read_csv("../datasets/HousesAverage_Age_Area.csv")
data
# Out:
#       Year  Code_District     Name_Dist  Code_NBHD            Name_NBHD  \
# 0     2018              1  Ciutat Vella          1             el Raval
# 1     2018              1  Ciutat Vella          1             el Raval
# 2     2018              1  Ciutat Vella          1             el Raval
# 3     2018              1  Ciutat Vella          1             el Raval
# 4     2018              1  Ciutat Vella          1             el Raval
# ...    ...            ...           ...        ...                  ...
# 2131  2019             10    Sant Martí         73  la Verneda i la Pau
# 2132  2019             10    Sant Martí         73  la Verneda i la Pau
# 2133  2019             10    Sant Martí         73  la Verneda i la Pau
# 2134  2019             10    Sant Martí         73  la Verneda i la Pau
# 2135  2019             10    Sant Martí         73  la Verneda i la Pau
#
#       Censal_Section  Average_Age  Average_Area
# 0                  1         68.0          76.8
# ...

# %%
data = pd.read_csv("../datasets/Rent_Houses_Hist.csv")
data
# Out:
#       Year  Trimester  Code_District     Name_Dist  Code_NBHD  \
# 0     2019          1              1  Ciutat Vella          1
# 1     2019          1              1  Ciutat Vella          2
# 2     2019          1              1  Ciutat Vella          3
# 3     2019          1              1  Ciutat Vella          4
# 4     2019          1              2      Eixample          5
# ...    ...        ...            ...           ...        ...
# 3499  2014          4             10    Sant Martí         69
# 3500  2014          4             10    Sant Martí         70
# 3501  2014          4             10    Sant Martí         71
# 3502  2014          4             10    Sant Martí         72
# 3503  2014          4             10    Sant Martí         73
#
#                                          Name_NBHD             Description  \
# 0                                         el Raval     Average Euros/month
# ...

# %%
data = pd.read_csv("../datasets/Sale_Houses_Hist.csv")
data
# Out:
#        Year  Trimester  Code_District     Name_Dist  Code_NBHD  \
# 0      2019          1              1  Ciutat Vella          1
# 1      2019          1              1  Ciutat Vella          2
# 2      2019          1              1  Ciutat Vella          3
# 3      2019          1              1  Ciutat Vella          4
# 4      2019          1              2      Eixample          5
# ...     ...        ...            ...           ...        ...
# 10507  2014          4             10    Sant Martí         69
# 10508  2014          4             10    Sant Martí         70
# 10509  2014          4             10    Sant Martí         71
# 10510  2014          4             10    Sant Martí         72
# 10511  2014          4             10    Sant Martí         73
#
#                                           Name_NBHD         Description  \
# 0                                          el Raval  Thousands of Euros
# ...

# %%
data = pd.read_csv("../datasets/Type_Locals.csv")
data
# Out:
#        Year Code_District     Name_Dist Code_NBHD            Name_NBHD  \
# 0      2019             1  Ciutat Vella         1             el Raval
# 1      2019             1  Ciutat Vella         1             el Raval
# 2      2019             1  Ciutat Vella         1             el Raval
# 3      2019             1  Ciutat Vella         1             el Raval
# 4      2019             1  Ciutat Vella         1             el Raval
# ...     ...           ...           ...       ...                  ...
# 52714  2018            10    Sant Martí        73  la Verneda i la Pau
# 52715  2018            10    Sant Martí        73  la Verneda i la Pau
# 52716  2018            10    Sant Martí        73  la Verneda i la Pau
# 52717  2018            10    Sant Martí        73  la Verneda i la Pau
# 52718  2018            10    Sant Martí        73  la Verneda i la Pau
#
#       Censal_Section          Use Description        Amount
# ...

# %%
data = pd.read_csv("../datasets/Density_Hist.csv")
data
# Out:
#      Year  \
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# ..    ...
# 433  2014
# 434  2014
# 435  2014
# 436  2014
# 437  2014
#
#      Code_District  \
# 0                1
# 1                1
# 2                1
# 3                1
# 4                2
# ..             ...
# 433             10
# 434             10
# 435             10
# 436             10
# 437             10
#
#         Name_Dist  \
# 0    Ciutat Vella
# 1    Ciutat Vella
# 2    Ciutat Vella
# 3    Ciutat Vella
# 4        Eixample
# ..            ...
# 433    Sant Martí
# 434    Sant Martí
# 435    Sant Martí
# 436    Sant Martí
# 437    Sant Martí
#
#      Code_NBHD  \
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 433         69
# 434         70
# 435         71
# 436         72
# 437         73
#
#                                         Name_NBHD  \
# 0                                        el Raval
# ...
