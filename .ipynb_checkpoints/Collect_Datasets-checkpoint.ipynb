# %%
import pandas as pd
import numpy as np

# %%
import requests
import re
import seaborn as sns

# %%
pd.set_option('max_info_columns', 20)

# %% [markdown]
# # TITLE

# %%
data = pd.read_csv("datasets/2013_comp_vend_preu.csv")# Add the name of the file
data
# Out:
#       Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2013               1  Ciutat Vella           1
# 1    2013               1  Ciutat Vella           2
# 2    2013               1  Ciutat Vella           3
# 3    2013               1  Ciutat Vella           4
# 4    2013               2      Eixample           5
# ..    ...             ...           ...         ...
# 433  2013              10    Sant Martí          69
# 434  2013              10    Sant Martí          70
# 435  2013              10    Sant Martí          71
# 436  2013              10    Sant Martí          72
# 437  2013              10    Sant Martí          73
#
#                                         Nom_Barri      Preu_mitja_habitatge  \
# 0                                        el Raval     Total. Milers d'euros
# 1                                  el Barri Gòtic     Total. Milers d'euros
# 2                                  la Barceloneta     Total. Milers d'euros
# ...
